# %%
# !pip install opencv-python

# %%
import cv2
print('done')
# Out:
# done

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg")

cv2.imshow('Image',image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np

# %%
image = np.zeros((512,512,3),np.uint8)

cv2.line(image,(0,0),(511,511),(0,0,255),5)


cv2.imshow('Drawing',image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = np.zeros((512,512,3),np.uint8)

cv2.line(image,(0,0),(511,511),(0,0,255),5)
cv2.rectangle(image,(384,0),(510,128),(0,255,0),3)

cv2.imshow('Drawing',image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = np.zeros((512,512,3),np.uint8)

cv2.line(image,(0,0),(511,511),(0,0,255),5)
cv2.rectangle(image,(384,0),(510,128),(0,255,0),3)
cv2.circle(image,(447,63),63,(0,0,255),-1)
cv2.imshow('Drawing',image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg")
hist = cv2.calcHist([image],[0],None,[256],[0,256])

plt.plot(hist)
plt.show()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg",0)

cv2.imshow('Grayscale Image',image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg",0)

kernal = np.ones((5,5),np.float32)/25

convolved_image = cv2.filter2D(image,-1,kernal)

cv2.imshow('Convolved Image',convolved_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg",0)
blurred_image = cv2.GaussianBlur(image,(15,15),0)
cv2.imshow('Blurred Image',blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg")

kernal = np.array([[0,-1,0,],
                   [-1,5,-1],
                   [0,-1,0]])
sharpened_image = cv2.filter2D(image,-1,kernal)

cv2.imshow('Sharpend_Image',sharpened_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg")
channels = cv2.split(image)
colors = ('b','g','r')
for(channel,color) in zip(channels,colors):
    hist = cv2.calcHist([channel],[0],None,[256],[0,256])
    plt.plot(hist, color = color)

plt.show()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg",0)

_,binary_image = \
cv2.threshold(image,127,255,cv2.THRESH_BINARY)

cv2.imshow('Binary Image',binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Rahul kumar\Downloads\MS.Dhoni.jpg",0)
sobel_x =cv2.Sobel(image,cv2.CV_64F,1,0,ksize=5)
sobel_y =cv2.Sobel(image,cv2.CV_64F,0,1,ksize=5)

sobel_combined = cv2.magnitude(sobel_x, sobel_y)

cv2.imshow('Original Image',image)
cv2.imshow('Sobel X',sobel_x)
cv2.imshow('Sobel y',sobel_y)
cv2.imshow('Sobel combined',sobel_combined)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

while True:
    ret,frame = cap.read()
    cv2.imshow('Video Stream',frame)
    if cv2.waitKey(1)&0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
from datetime import datetime
faces_data = {'No_faces':[],'Time':[]}
import cv2
cap = cv2.VideoCapture(0)

# Create the haar cascade
faceCascade = \
cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

while(True):
    # Capture frame-by-frame

    ret, frame = cap.read()


    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)


    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5,
        minSize=(30, 30)
        #flags = cv2.CV_HAAR_SCALE_IMAGE
    )

    print("Found {0} faces!".format(len(faces)))
    samay = datetime.now().time()
    faces_data['No_faces'].append(len(faces))
    faces_data['Time'].append(samay)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)


    # Display the resulting frame
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# Found 0 faces!
# ...

# %%
import pandas as pd
face_info = pd.DataFrame(faces_data)

# %%
face_info
# Out:
#      No_faces             Time
# 0           0  13:20:11.933890
# 1           0  13:20:12.052099
# 2           0  13:20:12.108256
# 3           0  13:20:12.139581
# 4           0  13:20:12.202865
# ..        ...              ...
# 743         0  13:20:50.035706
# 744         0  13:20:50.078133
# 745         0  13:20:50.136737
# 746         1  13:20:50.171270
# 747         1  13:20:50.222645
#
# [748 rows x 2 columns]

# %%
face_info[face_info['No_faces'] ==1]
# Out:
#      No_faces             Time
# 139         1  13:20:18.004941
# 140         1  13:20:18.031082
# 141         1  13:20:18.052162
# 142         1  13:20:18.078460
# 143         1  13:20:18.102852
# ..        ...              ...
# 684         1  13:20:46.534466
# 685         1  13:20:46.616214
# 686         1  13:20:46.692406
# 746         1  13:20:50.171270
# 747         1  13:20:50.222645
#
# [110 rows x 2 columns]
